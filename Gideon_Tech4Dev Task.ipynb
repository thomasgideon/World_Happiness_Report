# %% [markdown]
# # World Happiness Report

# %% [markdown]
# The aim of this work is to assess or measure global happiness using the following variables: `life expectancy`, `economics`, `social support`, `absence of corruption`, `freedom`, and `generosity`.
#
# Using datasets from World Happiness Report over 2015, 2016, 2017, 2018, and 2019. We would with these datasets answer the following questions:
#
# * Which country is the happiest in the world?
# * What are the most important contributing factors to a nation’s happiness?
# * Is overall happiness increasing or decreasing?

# %% [markdown]
# ### Importing necessary libraries

# %%
#importing necessary libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ### Loading-in the datasets

# %%
data_2015 = pd.read_csv('2015.csv')
data_2016 = pd.read_csv('2016.csv')
data_2017 = pd.read_csv('2017.csv')
data_2018 = pd.read_csv('2018.csv')
data_2019 = pd.read_csv('2019.csv')

# %% [markdown]
# ### Data Inspection

# %%
data_2015.head()
# Out:
#        Country          Region  Happiness Rank  Happiness Score  \
# 0  Switzerland  Western Europe               1            7.587
# 1      Iceland  Western Europe               2            7.561
# 2      Denmark  Western Europe               3            7.527
# 3       Norway  Western Europe               4            7.522
# 4       Canada   North America               5            7.427
#
#    Standard Error  Economy (GDP per Capita)   Family  \
# 0         0.03411                   1.39651  1.34951
# 1         0.04884                   1.30232  1.40223
# 2         0.03328                   1.32548  1.36058
# 3         0.03880                   1.45900  1.33095
# 4         0.03553                   1.32629  1.32261
#
#    Health (Life Expectancy)  Freedom  Trust (Government Corruption)  \
# 0                   0.94143  0.66557                        0.41978
# 1                   0.94784  0.62877                        0.14145
# ...

# %%
data_2016.head()
# Out:
#        Country          Region  Happiness Rank  Happiness Score  \
# 0      Denmark  Western Europe               1            7.526
# 1  Switzerland  Western Europe               2            7.509
# 2      Iceland  Western Europe               3            7.501
# 3       Norway  Western Europe               4            7.498
# 4      Finland  Western Europe               5            7.413
#
#    Lower Confidence Interval  Upper Confidence Interval  \
# 0                      7.460                      7.592
# 1                      7.428                      7.590
# 2                      7.333                      7.669
# 3                      7.421                      7.575
# 4                      7.351                      7.475
#
#    Economy (GDP per Capita)   Family  Health (Life Expectancy)  Freedom  \
# 0                   1.44178  1.16374                   0.79504  0.57941
# 1                   1.52733  1.14524                   0.86303  0.58557
# ...

# %%
data_2017.head()
# Out:
#        Country  Happiness.Rank  Happiness.Score  Whisker.high  Whisker.low  \
# 0       Norway               1            7.537      7.594445     7.479556
# 1      Denmark               2            7.522      7.581728     7.462272
# 2      Iceland               3            7.504      7.622030     7.385970
# 3  Switzerland               4            7.494      7.561772     7.426227
# 4      Finland               5            7.469      7.527542     7.410458
#
#    Economy..GDP.per.Capita.    Family  Health..Life.Expectancy.   Freedom  \
# 0                  1.616463  1.533524                  0.796667  0.635423
# 1                  1.482383  1.551122                  0.792566  0.626007
# 2                  1.480633  1.610574                  0.833552  0.627163
# 3                  1.564980  1.516912                  0.858131  0.620071
# 4                  1.443572  1.540247                  0.809158  0.617951
#
#    Generosity  Trust..Government.Corruption.  Dystopia.Residual
# ...

# %%
data_2018.head()
# Out:
#    Overall rank Country or region  Score  GDP per capita  Social support  \
# 0             1           Finland  7.632           1.305           1.592
# 1             2            Norway  7.594           1.456           1.582
# 2             3           Denmark  7.555           1.351           1.590
# 3             4           Iceland  7.495           1.343           1.644
# 4             5       Switzerland  7.487           1.420           1.549
#
#    Healthy life expectancy  Freedom to make life choices  Generosity  \
# 0                    0.874                         0.681       0.202
# 1                    0.861                         0.686       0.286
# 2                    0.868                         0.683       0.284
# 3                    0.914                         0.677       0.353
# 4                    0.927                         0.660       0.256
#
#    Perceptions of corruption
# 0                      0.393
# 1                      0.340
# ...

# %%
data_2019.head()
# Out:
#    Overall rank Country or region  Score  GDP per capita  Social support  \
# 0             1           Finland  7.769           1.340           1.587
# 1             2           Denmark  7.600           1.383           1.573
# 2             3            Norway  7.554           1.488           1.582
# 3             4           Iceland  7.494           1.380           1.624
# 4             5       Netherlands  7.488           1.396           1.522
#
#    Healthy life expectancy  Freedom to make life choices  Generosity  \
# 0                    0.986                         0.596       0.153
# 1                    0.996                         0.592       0.252
# 2                    1.028                         0.603       0.271
# 3                    1.026                         0.591       0.354
# 4                    0.999                         0.557       0.322
#
#    Perceptions of corruption
# 0                      0.393
# 1                      0.410
# ...

# %% [markdown]
# ### Data Cleaning Procedures
#
# Discrepancies were observed with the different column names in the yearly data. These descrepancies were handled in the following cells.
#
# It could also be noted that 9 common variables were deemed essential for these analysis, and they include `Rank`, `Country`, `Happiness Score`, `Life Expectancy`, `Economics`, `Social Support`, `Absence of Corruption`, `Freedom`, and `Generosity`.
#
# The different data were eventually combined into one for ease of analysis; the combined data was then inspected for missing values. A single variable, `Trust (Government Corruption)` was found to contain just a missing value. Owing to the number of missing values, the row with the missing data was dropped.

# %%
#It is observed that there are discrepancies in the columns names
#And there are also 8 common variables
#I shall, therefore, extract these variables from each dataset
print('The columns in the 2015 dataset are: \n', data_2015.columns, '\n')
print('The columns in the 2016 dataset are: \n', data_2016.columns, '\n')
print('The columns in the 2017 dataset are: \n', data_2017.columns, '\n')
print('The columns in the 2018 dataset are: \n', data_2018.columns, '\n')
print('The columns in the 2019 dataset are: \n', data_2019.columns)
# Out:
# The columns in the 2015 dataset are:
#  Index(['Country', 'Region', 'Happiness Rank', 'Happiness Score',
#        'Standard Error', 'Economy (GDP per Capita)', 'Family',
#        'Health (Life Expectancy)', 'Freedom', 'Trust (Government Corruption)',
#        'Generosity', 'Dystopia Residual'],
#       dtype='object')
#
# The columns in the 2016 dataset are:
#  Index(['Country', 'Region', 'Happiness Rank', 'Happiness Score',
#        'Lower Confidence Interval', 'Upper Confidence Interval',
#        'Economy (GDP per Capita)', 'Family', 'Health (Life Expectancy)',
#        'Freedom', 'Trust (Government Corruption)', 'Generosity',
#        'Dystopia Residual'],
#       dtype='object')
#
# The columns in the 2017 dataset are:
#  Index(['Country', 'Happiness.Rank', 'Happiness.Score', 'Whisker.high',
#        'Whisker.low', 'Economy..GDP.per.Capita.', 'Family',
#        'Health..Life.Expectancy.', 'Freedom', 'Generosity',
#        'Trust..Government.Corruption.', 'Dystopia.Residual'],
# ...

# %%
data_2015 = data_2015[['Country', 'Happiness Rank', 'Happiness Score','Economy (GDP per Capita)',
                      'Family',
       'Health (Life Expectancy)', 'Freedom', 'Trust (Government Corruption)',
       'Generosity']]
data_2015.sample(5)
# Out:
#          Country  Happiness Rank  Happiness Score  Economy (GDP per Capita)  \
# 11    Costa Rica              12            7.226                   0.95578
# 150  Ivory Coast             151            3.655                   0.46534
# 92     Macedonia              93            5.007                   0.91851
# 57          Peru              58            5.824                   0.90019
# 60      Malaysia              61            5.770                   1.12486
#
#       Family  Health (Life Expectancy)  Freedom  \
# 11   1.23788                   0.86027  0.63376
# 150  0.77115                   0.15185  0.46866
# 92   1.00232                   0.73545  0.33457
# 57   0.97459                   0.73017  0.41496
# 60   1.07023                   0.72394  0.53024
#
#      Trust (Government Corruption)  Generosity
# 11                         0.10583     0.25497
# 150                        0.17922     0.20165
# 92                         0.05327     0.22359
# ...

# %%
data_2016 = data_2016[['Country', 'Happiness Rank', 'Happiness Score',
       'Economy (GDP per Capita)', 'Family', 'Health (Life Expectancy)',
       'Freedom', 'Trust (Government Corruption)', 'Generosity']]
data_2016.sample(5)
# Out:
#      Country  Happiness Rank  Happiness Score  Economy (GDP per Capita)  \
# 133    Gabon             134            4.121                   1.15851
# 63      Peru              64            5.743                   0.99602
# 143     Chad             144            3.763                   0.42214
# 132    Sudan             133            4.139                   0.63069
# 18   Ireland              19            6.907                   1.48341
#
#       Family  Health (Life Expectancy)  Freedom  \
# 133  0.72368                   0.34940  0.28098
# 63   0.81255                   0.62994  0.37502
# 143  0.63178                   0.03824  0.12807
# 132  0.81928                   0.29759  0.00000
# 18   1.16157                   0.81455  0.54008
#
#      Trust (Government Corruption)  Generosity
# 133                        0.09314     0.06244
# 63                         0.05292     0.14527
# 143                        0.04952     0.18667
# 132                        0.10039     0.18077
# ...

# %%
data_2017 = data_2017[['Country', 'Happiness.Rank', 'Happiness.Score','Economy..GDP.per.Capita.', 'Family',
       'Health..Life.Expectancy.','Freedom', 'Generosity','Trust..Government.Corruption.']]

data_2017.sample(5)
# Out:
#          Country  Happiness.Rank  Happiness.Score  Economy..GDP.per.Capita.  \
# 35      Colombia              36            6.357                  1.070622
# 68        Turkey              69            5.500                  1.198274
# 120      Armenia             121            4.376                  0.900597
# 71   Philippines              72            5.430                  0.857699
# 67         Libya              68            5.525                  1.101803
#
#        Family  Health..Life.Expectancy.   Freedom  Generosity  \
# 35   1.402183                  0.595028  0.477487    0.149014
# 68   1.337753                  0.637606  0.300741    0.046693
# 120  1.007484                  0.637524  0.198303    0.083488
# 71   1.253918                  0.468009  0.585215    0.193513
# 67   1.357564                  0.520169  0.465733    0.152074
#
#      Trust..Government.Corruption.
# 35                        0.046669
# 68                        0.099672
# ...

# %%
data_2018 = data_2018[['Country or region', 'Overall rank', 'Score', 'GDP per capita',
       'Social support', 'Healthy life expectancy',
       'Freedom to make life choices', 'Generosity',
       'Perceptions of corruption']]

data_2018.sample(5)
# Out:
#           Country or region  Overall rank  Score  GDP per capita  \
# 60                   Cyprus            61  5.762           1.229
# 92   Bosnia and Herzegovina            93  5.129           0.915
# 63                 Paraguay            64  5.681           0.835
# 109                    Laos           110  4.623           0.720
# 23                   Mexico            24  6.488           1.038
#
#      Social support  Healthy life expectancy  Freedom to make life choices  \
# 60            1.191                    0.909                         0.423
# 92            1.078                    0.758                         0.280
# 63            1.522                    0.615                         0.541
# 109           1.034                    0.441                         0.626
# 23            1.252                    0.761                         0.479
#
#      Generosity  Perceptions of corruption
# 60        0.202                      0.035
# ...

# %%
data_2019 = data_2019[['Country or region', 'Overall rank', 'Score', 'GDP per capita',
       'Social support', 'Healthy life expectancy',
       'Freedom to make life choices', 'Generosity',
       'Perceptions of corruption']]

data_2019.sample(5)
# Out:
#     Country or region  Overall rank  Score  GDP per capita  Social support  \
# 123           Tunisia           124  4.461           0.921           1.000
# 19     Czech Republic            20  6.852           1.269           1.487
# 36            Bahrain            37  6.199           1.362           1.368
# 31             Brazil            32  6.300           1.004           1.439
# 23             France            24  6.592           1.324           1.472
#
#      Healthy life expectancy  Freedom to make life choices  Generosity  \
# 123                    0.815                         0.167       0.059
# 19                     0.920                         0.457       0.046
# 36                     0.871                         0.536       0.255
# 31                     0.802                         0.390       0.099
# 23                     1.045                         0.436       0.111
#
#      Perceptions of corruption
# 123                      0.055
# ...

# %%
print('The columns in the 2015 dataset are: \n', data_2015.columns, '\n')
print('The columns in the 2016 dataset are: \n', data_2016.columns, '\n')
print('The columns in the 2017 dataset are: \n', data_2017.columns, '\n')
print('The columns in the 2018 dataset are: \n', data_2018.columns, '\n')
print('The columns in the 2019 dataset are: \n', data_2019.columns)
# Out:
# The columns in the 2015 dataset are:
#  Index(['Country', 'Happiness Rank', 'Happiness Score',
#        'Economy (GDP per Capita)', 'Family', 'Health (Life Expectancy)',
#        'Freedom', 'Trust (Government Corruption)', 'Generosity'],
#       dtype='object')
#
# The columns in the 2016 dataset are:
#  Index(['Country', 'Happiness Rank', 'Happiness Score',
#        'Economy (GDP per Capita)', 'Family', 'Health (Life Expectancy)',
#        'Freedom', 'Trust (Government Corruption)', 'Generosity'],
#       dtype='object')
#
# The columns in the 2017 dataset are:
#  Index(['Country', 'Happiness.Rank', 'Happiness.Score',
#        'Economy..GDP.per.Capita.', 'Family', 'Health..Life.Expectancy.',
#        'Freedom', 'Generosity', 'Trust..Government.Corruption.'],
#       dtype='object')
#
# The columns in the 2018 dataset are:
#  Index(['Country or region', 'Overall rank', 'Score', 'GDP per capita',
#        'Social support', 'Healthy life expectancy',
# ...

# %%
#Rearranging the 2017 dataset
data_2017 = data_2017[['Country', 'Happiness.Rank', 'Happiness.Score','Economy..GDP.per.Capita.', 'Family',
       'Health..Life.Expectancy.','Freedom','Trust..Government.Corruption.', 'Generosity']]

data_2018 = data_2018[['Country or region', 'Overall rank', 'Score', 'GDP per capita', 'Social support',
       'Healthy life expectancy', 'Freedom to make life choices', 'Perceptions of corruption','Generosity']]

data_2019 = data_2019[['Country or region', 'Overall rank', 'Score', 'GDP per capita', 'Social support',
       'Healthy life expectancy', 'Freedom to make life choices', 
       'Perceptions of corruption','Generosity']]

# %%
data_2017.sample(5)
# Out:
#          Country  Happiness.Rank  Happiness.Score  Economy..GDP.per.Capita.  \
# 6         Canada               7            7.316                  1.479204
# 53        Latvia              54            5.850                  1.260749
# 73        Jordan              74            5.336                  0.991012
# 41      Malaysia              42            6.084                  1.291215
# 146  South Sudan             147            3.591                  0.397249
#
#        Family  Health..Life.Expectancy.   Freedom  \
# 6    1.481349                  0.834558  0.611101
# 53   1.404715                  0.638567  0.325708
# 73   1.239089                  0.604590  0.418421
# 41   1.284646                  0.618784  0.402265
# 146  0.601323                  0.163486  0.147062
#
#      Trust..Government.Corruption.  Generosity
# 6                         0.287372    0.435540
# 53                        0.073843    0.153075
# 73                        0.119803    0.172170
# ...

# %%
data_2018.sample(5)
# Out:
#     Country or region  Overall rank  Score  GDP per capita  Social support  \
# 34           Malaysia            35  6.322           1.161           1.258
# 57    Northern Cyprus            58  5.835           1.229           1.211
# 56        South Korea            57  5.875           1.266           1.204
# 110           Tunisia           111  4.592           0.900           0.906
# 32       Saudi Arabia            33  6.371           1.379           1.331
#
#      Healthy life expectancy  Freedom to make life choices  \
# 34                     0.669                         0.356
# 57                     0.909                         0.495
# 56                     0.955                         0.244
# 110                    0.690                         0.271
# 32                     0.633                         0.509
#
#      Perceptions of corruption  Generosity
# 34                       0.059       0.311
# 57                       0.154       0.179
# ...

# %%
data_2019.sample(5)
# Out:
#      Country or region  Overall rank  Score  GDP per capita  Social support  \
# 38   Trinidad & Tobago            39  6.192           1.231           1.477
# 90             Lebanon            91  5.197           0.987           1.224
# 96            Bulgaria            97  5.011           1.092           1.513
# 135             Uganda           136  4.189           0.332           1.069
# 120              Kenya           121  4.509           0.512           0.983
#
#      Healthy life expectancy  Freedom to make life choices  \
# 38                     0.713                         0.489
# 90                     0.815                         0.216
# 96                     0.815                         0.311
# 135                    0.443                         0.356
# 120                    0.581                         0.431
#
#      Perceptions of corruption  Generosity
# 38                       0.016       0.185
# 90                       0.027       0.166
# ...

# %%
print('The columns in the 2015 dataset are: \n', data_2015.columns, '\n')
print('The columns in the 2017 dataset are: \n', data_2017.columns, '\n')
print('The columns in the 2018 dataset are: \n', data_2018.columns, '\n')
print('The columns in the 2019 dataset are: \n', data_2019.columns)
# Out:
# The columns in the 2015 dataset are:
#  Index(['Country', 'Happiness Rank', 'Happiness Score',
#        'Economy (GDP per Capita)', 'Family', 'Health (Life Expectancy)',
#        'Freedom', 'Trust (Government Corruption)', 'Generosity'],
#       dtype='object')
#
# The columns in the 2017 dataset are:
#  Index(['Country', 'Happiness.Rank', 'Happiness.Score',
#        'Economy..GDP.per.Capita.', 'Family', 'Health..Life.Expectancy.',
#        'Freedom', 'Trust..Government.Corruption.', 'Generosity'],
#       dtype='object')
#
# The columns in the 2018 dataset are:
#  Index(['Country or region', 'Overall rank', 'Score', 'GDP per capita',
#        'Social support', 'Healthy life expectancy',
#        'Freedom to make life choices', 'Perceptions of corruption',
#        'Generosity'],
#       dtype='object')
#
# The columns in the 2019 dataset are:
#  Index(['Country or region', 'Overall rank', 'Score', 'GDP per capita',
#        'Social support', 'Healthy life expectancy',
# ...

# %%
#Changing the column names of 2017, 2018, and 2019 datasets to the same as 2015
data_2017.columns = data_2015.columns
data_2018.columns = data_2015.columns
data_2019.columns = data_2015.columns

# %%
print('The columns in the 2017 dataset are: \n', data_2017.columns, '\n')
print('The columns in the 2018 dataset are: \n', data_2018.columns, '\n')
print('The columns in the 2019 dataset are: \n', data_2019.columns)
# Out:
# The columns in the 2017 dataset are:
#  Index(['Country', 'Happiness Rank', 'Happiness Score',
#        'Economy (GDP per Capita)', 'Family', 'Health (Life Expectancy)',
#        'Freedom', 'Trust (Government Corruption)', 'Generosity'],
#       dtype='object')
#
# The columns in the 2018 dataset are:
#  Index(['Country', 'Happiness Rank', 'Happiness Score',
#        'Economy (GDP per Capita)', 'Family', 'Health (Life Expectancy)',
#        'Freedom', 'Trust (Government Corruption)', 'Generosity'],
#       dtype='object')
#
# The columns in the 2019 dataset are:
#  Index(['Country', 'Happiness Rank', 'Happiness Score',
#        'Economy (GDP per Capita)', 'Family', 'Health (Life Expectancy)',
#        'Freedom', 'Trust (Government Corruption)', 'Generosity'],
#       dtype='object')

# %%
data_2017.sample(5)
# Out:
#      Country  Happiness Rank  Happiness Score  Economy (GDP per Capita)  \
# 120  Armenia             121            4.376                  0.900597
# 151    Syria             152            3.462                  0.777153
# 45    Poland              46            5.973                  1.291788
# 19     Chile              20            6.652                  1.252785
# 2    Iceland               3            7.504                  1.480633
#
#        Family  Health (Life Expectancy)   Freedom  \
# 120  1.007484                  0.637524  0.198303
# 151  0.396103                  0.500533  0.081539
# 45   1.445712                  0.699475  0.520342
# 19   1.284025                  0.819480  0.376895
# 2    1.610574                  0.833552  0.627163
#
#      Trust (Government Corruption)  Generosity
# 120                       0.026674    0.083488
# 151                       0.151347    0.493664
# 45                        0.059308    0.158466
# ...

# %%
print('The columns in the 2015 dataset are: \n', data_2015.columns, '\n')
print('The columns in the 2016 dataset are: \n', data_2016.columns, '\n')
print('The columns in the 2017 dataset are: \n', data_2017.columns, '\n')
print('The columns in the 2018 dataset are: \n', data_2018.columns, '\n')
print('The columns in the 2019 dataset are: \n', data_2019.columns)
# Out:
# The columns in the 2015 dataset are:
#  Index(['Country', 'Happiness Rank', 'Happiness Score',
#        'Economy (GDP per Capita)', 'Family', 'Health (Life Expectancy)',
#        'Freedom', 'Trust (Government Corruption)', 'Generosity'],
#       dtype='object')
#
# The columns in the 2016 dataset are:
#  Index(['Country', 'Happiness Rank', 'Happiness Score',
#        'Economy (GDP per Capita)', 'Family', 'Health (Life Expectancy)',
#        'Freedom', 'Trust (Government Corruption)', 'Generosity'],
#       dtype='object')
#
# The columns in the 2017 dataset are:
#  Index(['Country', 'Happiness Rank', 'Happiness Score',
#        'Economy (GDP per Capita)', 'Family', 'Health (Life Expectancy)',
#        'Freedom', 'Trust (Government Corruption)', 'Generosity'],
#       dtype='object')
#
# The columns in the 2018 dataset are:
#  Index(['Country', 'Happiness Rank', 'Happiness Score',
#        'Economy (GDP per Capita)', 'Family', 'Health (Life Expectancy)',
# ...

# %%
#Creating the column 'Year' for identification
data_2015['Year'] = 2015
data_2016['Year'] = 2016
data_2017['Year'] = 2017
data_2018['Year'] = 2018
data_2019['Year'] = 2019

# %%
data_2015.head()
# Out:
#        Country  Happiness Rank  Happiness Score  Economy (GDP per Capita)  \
# 0  Switzerland               1            7.587                   1.39651
# 1      Iceland               2            7.561                   1.30232
# 2      Denmark               3            7.527                   1.32548
# 3       Norway               4            7.522                   1.45900
# 4       Canada               5            7.427                   1.32629
#
#     Family  Health (Life Expectancy)  Freedom  Trust (Government Corruption)  \
# 0  1.34951                   0.94143  0.66557                        0.41978
# 1  1.40223                   0.94784  0.62877                        0.14145
# 2  1.36058                   0.87464  0.64938                        0.48357
# 3  1.33095                   0.88521  0.66973                        0.36503
# 4  1.32261                   0.90563  0.63297                        0.32957
#
#    Generosity  Year
# 0     0.29678  2015
# ...

# %%
#Combinning the different datasets into a singular one
data_combined = pd.concat([data_2015, data_2016, data_2017,data_2018,data_2019])

# %%
data_combined.head(10)
# Out:
#        Country  Happiness Rank  Happiness Score  Economy (GDP per Capita)  \
# 0  Switzerland               1            7.587                   1.39651
# 1      Iceland               2            7.561                   1.30232
# 2      Denmark               3            7.527                   1.32548
# 3       Norway               4            7.522                   1.45900
# 4       Canada               5            7.427                   1.32629
# 5      Finland               6            7.406                   1.29025
# 6  Netherlands               7            7.378                   1.32944
# 7       Sweden               8            7.364                   1.33171
# 8  New Zealand               9            7.286                   1.25018
# 9    Australia              10            7.284                   1.33358
#
#     Family  Health (Life Expectancy)  Freedom  Trust (Government Corruption)  \
# ...

# %%
data_combined.sample(10)
# Out:
#                   Country  Happiness Rank  Happiness Score  \
# 30                 Panama              31            6.321
# 57                   Peru              58            5.824
# 65              Mauritius              66            5.648
# 83                  China              84            5.140
# 121                 Kenya             122            4.356
# 49                 Belize              50            5.956
# 137               Ukraine             138            4.103
# 52                 Latvia              53            5.933
# 20   United Arab Emirates              21            6.825
# 40                Bahrain              41            6.087
#
#      Economy (GDP per Capita)    Family  Health (Life Expectancy)   Freedom  \
# 30                   1.149000  1.442000                  0.910000  0.516000
# 57                   0.900190  0.974590                  0.730170  0.414960
# 65                   1.143720  0.756950                  0.661890  0.461450
# ...

# %%
data_combined.columns
# Out:
# Index(['Country', 'Happiness Rank', 'Happiness Score',
#        'Economy (GDP per Capita)', 'Family', 'Health (Life Expectancy)',
#        'Freedom', 'Trust (Government Corruption)', 'Generosity', 'Year'],
#       dtype='object')

# %%
#Checking for the number of rows in each yearly data
print(len(data_2015))
print(len(data_2016))
print(len(data_2017))
print(len(data_2018))
print(len(data_2019))
# Out:
# 158
# 157
# 155
# 156
# 156

# %%
#In all, there are 782 rows in the combined data
print(len(data_combined))
# Out:
# 782

# %% [markdown]
# ### Further Inspections

# %%
data_combined.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 782 entries, 0 to 155
# Data columns (total 10 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   Country                        782 non-null    object
#  1   Happiness Rank                 782 non-null    int64
#  2   Happiness Score                782 non-null    float64
#  3   Economy (GDP per Capita)       782 non-null    float64
#  4   Family                         782 non-null    float64
#  5   Health (Life Expectancy)       782 non-null    float64
#  6   Freedom                        782 non-null    float64
#  7   Trust (Government Corruption)  781 non-null    float64
#  8   Generosity                     782 non-null    float64
#  9   Year                           782 non-null    int64
# dtypes: float64(7), int64(2), object(1)
# memory usage: 67.2+ KB

# %% [markdown]
# The result above revealed that there are `Ten (10)` numerical variables and `One (1)` character variable.

# %%
data_combined.isna().sum()
# Out:
# Country                          0
# Happiness Rank                   0
# Happiness Score                  0
# Economy (GDP per Capita)         0
# Family                           0
# Health (Life Expectancy)         0
# Freedom                          0
# Trust (Government Corruption)    1
# Generosity                       0
# Year                             0
# dtype: int64

# %% [markdown]
# The result above reveals the presence of a missing value under variable `Trust (Government Corruption)`. I shall replace with an appropriate strategy in the cells that follow.
#
# However, I would like to investigate into the data further.

# %%
data_combined.describe().T
# Out:
#                                count         mean        std       min  \
# Happiness Rank                 782.0    78.698210  45.182384     1.000
# Happiness Score                782.0     5.379018   1.127456     2.693
# Economy (GDP per Capita)       782.0     0.916047   0.407340     0.000
# Family                         782.0     1.078392   0.329548     0.000
# Health (Life Expectancy)       782.0     0.612416   0.248309     0.000
# Freedom                        782.0     0.411091   0.152880     0.000
# Trust (Government Corruption)  781.0     0.125436   0.105816     0.000
# Generosity                     782.0     0.218576   0.122321     0.000
# Year                           782.0  2016.993606   1.417364  2015.000
#
#                                        25%          50%          75%  \
# Happiness Rank                   40.000000    79.000000   118.000000
# Happiness Score                   4.509750     5.322000     6.189500
# ...

# %% [markdown]
# Looking at the descriptive table above, one would see the closeness between the Mean (0.125436) and Standard Deviation (0.105816) of `Trust (Government Corruption)`. There is also a wide gap between the Maximum value (or 100th pecentile), **0.551910** and the 75th percentile, **0.156030**. This gap suggests the presence of outliers above the upper whisker of the box plot (or right skewness in the histogram). We would, however, comfirm that using visuals like Box plots and Histogram.

# %%
h = data_combined['Trust (Government Corruption)'].hist(bins = 25, figsize = (8,8),
             xlabelsize = '10', ylabelsize = '10')
sns.despine(left = True, bottom = True)

# %% [markdown]
# The histogram above represents the distribution for `Trust (Government Corruption)`, and it reveals a skewness to the right.

# %%
sns.distplot(data_combined['Trust (Government Corruption)'], hist=True, kde=True, 
             color = 'darkblue', 
             hist_kws={'edgecolor':'black'},
             kde_kws={'linewidth': 4})
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='Trust (Government Corruption)', ylabel='Density'>

# %%
data_combined['Trust (Government Corruption)'].plot(kind='box', 
                   subplots=True, 
                   layout=(3, 2), 
                   sharex=False, 
                   figsize=(16, 24))
plt.show()

# %% [markdown]
# The graphs have affirmed my claims about the presence of outliers and the skewness of the distribution. In the light of this, it is besst to replace the missing data in `Trust (Government Corruption)` with the `Modal value` or `Median value` and not the `Mean value`. Reason being that the mean statistics is not robust towards outliers while mode and median are.

# %% [markdown]
# #### Filling Missing Value with the Median

# %%
data_combined['Trust (Government Corruption)'].fillna(data_combined['Trust (Government Corruption)'].median(), inplace = True)

# %%
data_combined.isna().sum()
# Out:
# Country                          0
# Happiness Rank                   0
# Happiness Score                  0
# Economy (GDP per Capita)         0
# Family                           0
# Health (Life Expectancy)         0
# Freedom                          0
# Trust (Government Corruption)    0
# Generosity                       0
# Year                             0
# dtype: int64

# %% [markdown]
# The dataset has been cleaned and made ready for analysis and visualizations.

# %%
data_combined.columns = ['Country', 'Rank', 'Happiness Score', 'Economics', 'Social Support',
                        'Life Expectancy', 'Freedom', 'Absence of Corruption', 'Generosity', 'Year']

data_combined.head()
# Out:
#        Country  Rank  Happiness Score  Economics  Social Support  \
# 0  Switzerland     1            7.587    1.39651         1.34951
# 1      Iceland     2            7.561    1.30232         1.40223
# 2      Denmark     3            7.527    1.32548         1.36058
# 3       Norway     4            7.522    1.45900         1.33095
# 4       Canada     5            7.427    1.32629         1.32261
#
#    Life Expectancy  Freedom  Absence of Corruption  Generosity  Year
# 0          0.94143  0.66557                0.41978     0.29678  2015
# 1          0.94784  0.62877                0.14145     0.43630  2015
# 2          0.87464  0.64938                0.48357     0.34139  2015
# 3          0.88521  0.66973                0.36503     0.34699  2015
# 4          0.90563  0.63297                0.32957     0.45811  2015

# %% [markdown]
# ### Question 1: Which country is the happiest in the world?
# To answer this question, we shall rely on variable `Happiness Score`, and infact, it is just enough to sort the dataset, by `Happiness Score`, in descending order.

# %%
data_2015.sort_values(by = 'Happiness Score', ascending = False)
# Out:
#          Country  Happiness Rank  Happiness Score  Economy (GDP per Capita)  \
# 0    Switzerland               1            7.587                   1.39651
# 1        Iceland               2            7.561                   1.30232
# 2        Denmark               3            7.527                   1.32548
# 3         Norway               4            7.522                   1.45900
# 4         Canada               5            7.427                   1.32629
# ..           ...             ...              ...                       ...
# 153       Rwanda             154            3.465                   0.22208
# 154        Benin             155            3.340                   0.28665
# 155        Syria             156            3.006                   0.66320
# 156      Burundi             157            2.905                   0.01530
# 157         Togo             158            2.839                   0.20868
#
#       Family  Health (Life Expectancy)  Freedom  \
# ...

# %% [markdown]
# The result above revealed that in `2015`, **Switzerland** was the happiest country, with a score of **7.587**.

# %%
data_2016.sort_values(by = 'Happiness Score', ascending = False)
# Out:
#          Country  Happiness Rank  Happiness Score  Economy (GDP per Capita)  \
# 0        Denmark               1            7.526                   1.44178
# 1    Switzerland               2            7.509                   1.52733
# 2        Iceland               3            7.501                   1.42666
# 3         Norway               4            7.498                   1.57744
# 4        Finland               5            7.413                   1.40598
# ..           ...             ...              ...                       ...
# 152        Benin             153            3.484                   0.39499
# 153  Afghanistan             154            3.360                   0.38227
# 154         Togo             155            3.303                   0.28123
# 155        Syria             156            3.069                   0.74719
# 156      Burundi             157            2.905                   0.06831
#
#       Family  Health (Life Expectancy)  Freedom  \
# ...

# %% [markdown]
# The result above revealed that **Denmark** was the happiest country in `2016`, with a score of **7.526**.

# %%
data_2017.sort_values(by = 'Happiness Score', ascending = False)
# Out:
#                       Country  Happiness Rank  Happiness Score  \
# 0                      Norway               1            7.537
# 1                     Denmark               2            7.522
# 2                     Iceland               3            7.504
# 3                 Switzerland               4            7.494
# 4                     Finland               5            7.469
# ..                        ...             ...              ...
# 150                    Rwanda             151            3.471
# 151                     Syria             152            3.462
# 152                  Tanzania             153            3.349
# 153                   Burundi             154            2.905
# 154  Central African Republic             155            2.693
#
#      Economy (GDP per Capita)    Family  Health (Life Expectancy)   Freedom  \
# 0                    1.616463  1.533524                  0.796667  0.635423
# ...

# %% [markdown]
# The result above revealed that in `2017`, **Norway** was the happiest country, with a score of **7.537**.

# %%
data_2018.sort_values(by = 'Happiness Score', ascending = False)
# Out:
#                       Country  Happiness Rank  Happiness Score  \
# 0                     Finland               1            7.632
# 1                      Norway               2            7.594
# 2                     Denmark               3            7.555
# 3                     Iceland               4            7.495
# 4                 Switzerland               5            7.487
# ..                        ...             ...              ...
# 151                     Yemen             152            3.355
# 152                  Tanzania             153            3.303
# 153               South Sudan             154            3.254
# 154  Central African Republic             155            3.083
# 155                   Burundi             156            2.905
#
#      Economy (GDP per Capita)  Family  Health (Life Expectancy)  Freedom  \
# 0                       1.305   1.592                     0.874    0.681
# ...

# %% [markdown]
# The result above revealed that **Finland** was the happiest country in `2018`, with a score of **7.632**.

# %%
data_2019.sort_values(by = 'Happiness Score', ascending = False)
# Out:
#                       Country  Happiness Rank  Happiness Score  \
# 0                     Finland               1            7.769
# 1                     Denmark               2            7.600
# 2                      Norway               3            7.554
# 3                     Iceland               4            7.494
# 4                 Netherlands               5            7.488
# ..                        ...             ...              ...
# 151                    Rwanda             152            3.334
# 152                  Tanzania             153            3.231
# 153               Afghanistan             154            3.203
# 154  Central African Republic             155            3.083
# 155               South Sudan             156            2.853
#
#      Economy (GDP per Capita)  Family  Health (Life Expectancy)  Freedom  \
# 0                       1.340   1.587                     0.986    0.596
# ...

# %% [markdown]
# And the result revealed that in `2019`, **Finland** was again the happiest country with a score of **7.769**.

# %%
data_combined.sort_values(by = 'Happiness Score', ascending = False)
# Out:
#                       Country  Rank  Happiness Score  Economics  \
# 0                     Finland     1            7.769   1.340000
# 0                     Finland     1            7.632   1.305000
# 1                     Denmark     2            7.600   1.383000
# 1                      Norway     2            7.594   1.456000
# 0                 Switzerland     1            7.587   1.396510
# ..                        ...   ...              ...        ...
# 156                   Burundi   157            2.905   0.068310
# 153                   Burundi   154            2.905   0.091623
# 155               South Sudan   156            2.853   0.306000
# 157                      Togo   158            2.839   0.208680
# 154  Central African Republic   155            2.693   0.000000
#
#      Social Support  Life Expectancy   Freedom  Absence of Corruption  \
# 0          1.587000         0.986000  0.596000               0.393000
# ...

# %% [markdown]
# Sorting the combined dataset revealed, as seen above, that Finland is the happiest country in the world.
#
# Worthy of note is that, over the years, Finland recorded the highest happiness score of 7.769. I mean to say that this is the highest happiness score so far.
#
# **So, we would conclude that Finland is the happiest country in the word.**

# %% [markdown]
# ### Question 2: What are the most important contributing factors to a nation’s happiness?
#
# Evaluating the contribution of other factors to the nation's happiness would mean that we declare `Happiness Score` as the dependent variable and  the folloing as independent variables: `Happiness Rank`, `Happiness Score`,`Economy (GDP per Capita)`, `Family`, `Health (Life Expectancy)`,`Freedom`, `Trust (Government Corruption)`, `Generosity`.

# %% [markdown]
# First, we would like to view the distribution of `Happiness Score`.

# %%
fig = plt.figure(figsize=(8,6))
sns.distplot(data_combined['Happiness Score'])
plt.title('Distribution of Happiness Score')
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# Text(0.5, 1.0, 'Distribution of Happiness Score')

# %% [markdown]
# As we can see above, the `Happiness Score` has values above 2.85 and below 7.76. So there is no single country with `Happiness Score` than 8.

# %% [markdown]
# To answer Question 2, we would use scatter plots to visualize the relationship between `Happiness Score` and other independent variables; correlation analysis to quantify these relationships; and regression to evaluate the impact of these relationships.

# %% [markdown]
# ### Happiness Score versus Economy (GDP per capita)
# The scatter plot reveals a positive relationship between the variables. This means that high GDP per capita contributes to happiness level of countries.

# %%
plt.figure(figsize=(8, 8))

plt.scatter(data_combined['Economics'], data_combined['Happiness Score'], color='r')

plt.xlabel('Economics')
plt.ylabel('Happiness Score')
# Out:
# Text(0, 0.5, 'Happiness Score')

# %% [markdown]
# ### Happiness Score versus Social Support
# The scatter plot reveals a positive relationship between the variables. This means that social support from friends and relatives when need arises contributes to happiness level of countries.
#
# So, it makes sense that we need social support to be happy.

# %%
plt.figure(figsize=(8, 8))

plt.scatter(data_combined['Social Support'], data_combined['Happiness Score'])

plt.xlabel('Social Support')
plt.ylabel('Happiness Score')
# Out:
# Text(0, 0.5, 'Happiness Score')

# %% [markdown]
# ### Happiness Score versus Life Expectancy
# The scatter plot also shows the existense of a positive relationship between `Life Expectancy` and `Happiness Score`, that is, if the country has a `High Life Expectancy`, it can also have a high `Happiness Score`.

# %%
plt.figure(figsize=(8, 8))

plt.scatter(data_combined['Life Expectancy'], data_combined['Happiness Score'], color='g')

plt.xlabel('Life Expectancy')
plt.ylabel('Happiness Score')
# Out:
# Text(0, 0.5, 'Happiness Score')

# %% [markdown]
# ### Happiness Score versus Freedom
# Freedom to make life choices has a positive relationship with `Happiness Score`. Choice and autonomy are more directly related to happiness than having lots of money. It gives us options to pursue meaning in our life, finding activities that stimulate and excite us. This is an essential aspect of feeling happy.

# %%
plt.figure(figsize=(8, 8))

plt.scatter(data_combined['Freedom'], data_combined['Happiness Score'], color='b')

plt.xlabel('Freedom')
plt.ylabel('Happiness Score')
# Out:
# Text(0, 0.5, 'Happiness Score')

# %% [markdown]
# ### Happiness Score versus Absence of Corruption

# %%
plt.figure(figsize=(8, 8))

plt.scatter(data_combined['Absence of Corruption'], data_combined['Happiness Score'], color='b')

plt.xlabel('Absence of Corruption')
plt.ylabel('Happiness Score')
# Out:
# Text(0, 0.5, 'Happiness Score')

# %% [markdown]
# ### Happiness Score versus Absence of Generosity

# %%
plt.figure(figsize=(8, 8))

plt.scatter(data_combined['Generosity'], data_combined['Happiness Score'], color='b')

plt.xlabel('Generosity')
plt.ylabel('Happiness Score')
# Out:
# Text(0, 0.5, 'Happiness Score')

# %% [markdown]
# ### Correlation Analysis to Quantify the Relationships

# %%
data_combined.columns
# Out:
# Index(['Country', 'Rank', 'Happiness Score', 'Economics', 'Social Support',
#        'Life Expectancy', 'Freedom', 'Absence of Corruption', 'Generosity',
#        'Year'],
#       dtype='object')

# %%
X = data_combined.drop(['Country', 'Rank', 'Year', 'Happiness Score'], axis =1)
Y = data_combined[['Happiness Score']]

# %%
X.head()
# Out:
#    Economics  Social Support  Life Expectancy  Freedom  Absence of Corruption  \
# 0    1.39651         1.34951          0.94143  0.66557                0.41978
# 1    1.30232         1.40223          0.94784  0.62877                0.14145
# 2    1.32548         1.36058          0.87464  0.64938                0.48357
# 3    1.45900         1.33095          0.88521  0.66973                0.36503
# 4    1.32629         1.32261          0.90563  0.63297                0.32957
#
#    Generosity
# 0     0.29678
# 1     0.43630
# 2     0.34139
# 3     0.34699
# 4     0.45811

# %%
Y.head()
# Out:
#    Happiness Score
# 0            7.587
# 1            7.561
# 2            7.527
# 3            7.522
# 4            7.427

# %% [markdown]
# #### Calculating Correlation Matrix

# %%
combined_corr = data_combined.corr()

combined_corr
# Out:
#                            Rank  Happiness Score  Economics  Social Support  \
# Rank                   1.000000        -0.992066  -0.794791       -0.644842
# Happiness Score       -0.992066         1.000000   0.789284        0.648799
# Economics             -0.794791         0.789284   1.000000        0.585966
# Social Support        -0.644842         0.648799   0.585966        1.000000
# Life Expectancy       -0.743655         0.742456   0.784338        0.572650
# Freedom               -0.537942         0.551258   0.340511        0.420361
# Absence of Corruption -0.371810         0.397484   0.303427        0.126707
# Generosity            -0.117713         0.137578  -0.014560       -0.037262
# Year                  -0.007768         0.007065   0.019768        0.367431
#
#                        Life Expectancy   Freedom  Absence of Corruption  \
# Rank                         -0.743655 -0.537942              -0.371810
# ...

# %% [markdown]
# The correlation matrix above reveals that the correlation coeffecient between:
#
# * `Happiness Score` and `Economics` is 0.789. This is a strong and positive relationship and it means that high GDP per capita or good economics result in happy living, and this is somewhat consistent through out the world.
#
# * `Happiness Score` and `Social Support` is 0.649. Thus is a strong and positive positive relationship and it means that high or increasing support from friends or families at times of needs contributes to nation's happiness.
#
# * The above patterns also follow with `Life Expectancy` and `Freedom`. However, there exist moderate or weak and positive relationship between `Happiness Score` and `Absence of Corruption` and `Generosity`.

# %%
#Plotting HeatMap
plt.figure(figsize=(10, 10))
sns.heatmap(combined_corr, annot=True)
# Out:
# <AxesSubplot:>

# %% [markdown]
# The correlation analysis above revealed that the most correlated factors to nations' happiness are `Economics (GDP per capita)`, `Life Expectancy (Health)` and `Social Support` and in that order. `Generosity` is least contributing to nations' happiness.

# %% [markdown]
# ### Building Linear Regression Model

# %%
from sklearn.model_selection import train_test_split
from sklearn.metrics import r2_score
from sklearn.preprocessing import RobustScaler

# %%
robust_scaler = RobustScaler()
X = robust_scaler.fit_transform(X) #scaling the features
x_train, x_test, y_train, y_test = train_test_split(X, Y, test_size=0.25)

# %%
print(x_train.shape)
# Out:
# (586, 6)

# %%
print(y_train.shape)
# Out:
# (586, 1)

# %%
print(x_test.shape)
# Out:
# (196, 6)

# %%
print(y_test.shape)
# Out:
# (196, 1)

# %%
from sklearn.linear_model import LinearRegression

linear_model = LinearRegression(normalize=True).fit(x_train, y_train)

# %%
print("Training_score : " , linear_model.score(x_train, y_train))
# Out:
# Training_score :  0.7633288687362534

# %%
y_pred = linear_model.predict(x_test)

# %%
from sklearn.metrics import r2_score

print("Testing_score : ", r2_score(y_test, y_pred))
# Out:
# Testing_score :  0.7620760584259528

# %% [markdown]
# Our model returned R-Squared = 76.2%. This means that about 76% variation in nations' happiness is explained by the predictors.

# %%
# MULTIPLE LR

#We can also use statsmodels to predict the Happiness Score.

import statsmodels.api as sm
X = data_combined[['Economics', 'Social Support', 'Life Expectancy', 'Freedom', 'Absence of Corruption', 'Generosity']]
Y = data_combined['Happiness Score']

X_sm = X = sm.add_constant(X)
model = sm.OLS(Y,X_sm)
model.fit().summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:        Happiness Score   R-squared:                       0.764
# Model:                            OLS   Adj. R-squared:                  0.762
# Method:                 Least Squares   F-statistic:                     418.2
# Date:                Thu, 04 Nov 2021   Prob (F-statistic):          4.35e-239
# Time:                        05:58:34   Log-Likelihood:                -638.32
# No. Observations:                 782   AIC:                             1291.
# Df Residuals:                     775   BIC:                             1323.
# Df Model:                           6
# Covariance Type:            nonrobust
# ...
#                             coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------------
# ...

# %% [markdown]
# The OLS Summary above reveals that all the features are significant positive predictors or contributors to nations' happiness, even at 99% confidence level. However, the most contributing factors or features are `Freedom`(1.4796), `Economics`(1.1477), `Life Expectancy`(1.0033), `Absence of Corruption`(0.8510), `Social Support`(0.6406), and `Generosity`(0.5941), in that other.
#
# For example, the above result means that a unit increase or change in people's freedom will cause or result in an increase in people's happiness by 1.4796 units. Other interpreations follow in the same way.

# %% [markdown]
# ### Question 3: Is overall happiness increasing or decreasing?

# %%
plt.plot(data_2015['Happiness Score'], linestyle = 'dotted')
plt.show()

# %%
plt.plot(data_2016['Happiness Score'], linestyle = 'dotted')
plt.show()

# %%
plt.plot(data_2017['Happiness Score'], linestyle = 'dotted')
plt.show()

# %%
plt.plot(data_2018['Happiness Score'], linestyle = 'dotted')
plt.show()

# %%
plt.plot(data_2019['Happiness Score'], linestyle = 'dotted')
plt.show()

# %% [markdown]
# From the line graphs above, we could say that, overall, happiness scores for nations are deacreasing.

# %% [markdown]
# ### Conclusion

# %% [markdown]
# Findings revealed a high focus on nations' economy (GDP per capita) and highly correlated features like health (life expectancy), support from relatives and friends, and freedom of people to make life's choices are great contributors to nations' happiness.
